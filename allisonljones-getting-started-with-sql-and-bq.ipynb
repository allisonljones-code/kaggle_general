# %% [markdown]
# **This notebook is an exercise in the [SQL](https://www.kaggle.com/learn/intro-to-sql) course.  You can reference the tutorial at [this link](https://www.kaggle.com/dansbecker/getting-started-with-sql-and-bigquery).**
#
# ---

# %% [markdown]
# # Introduction
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %%
# Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")
# Out:
# /usr/local/lib/python3.11/dist-packages/learntools/sql/ex1.py:64: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (type(fields_for_plotting[0] == str), "The first item in `fields_for_plotting` should be a string.")
# /usr/local/lib/python3.11/dist-packages/learntools/sql/ex1.py:65: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (type(fields_for_plotting[1] == str), "The second item in `fields_for_plotting` should be a string.")
# Using Kaggle's public dataset BigQuery integration.
# Setup Complete

# %% [markdown]
# Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
# List all the tables in the "Chicago Crime" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset
for table in tables:  
    print(table.table_id)
# Out:
# crime

# %%
num_tables = 1  # Store the answer as num_tables and then run this cell

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_1.hint()
#q_1.solution()

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
# Construct a reference to the "crime" table
table_ref = dataset_ref.table("crime")

# API request - fetch the table
table = client.get_table(table_ref)
table.schema

for field in table.schema:
    print(f"Column: {field.name:<25} Type: {field.field_type:<10} Mode: {field.mode}")
# Out:
# Column: unique_key                Type: INTEGER    Mode: REQUIRED
# Column: case_number               Type: STRING     Mode: NULLABLE
# Column: date                      Type: TIMESTAMP  Mode: NULLABLE
# Column: block                     Type: STRING     Mode: NULLABLE
# Column: iucr                      Type: STRING     Mode: NULLABLE
# Column: primary_type              Type: STRING     Mode: NULLABLE
# Column: description               Type: STRING     Mode: NULLABLE
# Column: location_description      Type: STRING     Mode: NULLABLE
# Column: arrest                    Type: BOOLEAN    Mode: NULLABLE
# Column: domestic                  Type: BOOLEAN    Mode: NULLABLE
# Column: beat                      Type: INTEGER    Mode: NULLABLE
# Column: district                  Type: INTEGER    Mode: NULLABLE
# Column: ward                      Type: INTEGER    Mode: NULLABLE
# Column: community_area            Type: INTEGER    Mode: NULLABLE
# Column: fbi_code                  Type: STRING     Mode: NULLABLE
# Column: x_coordinate              Type: FLOAT      Mode: NULLABLE
# Column: y_coordinate              Type: FLOAT      Mode: NULLABLE
# Column: year                      Type: INTEGER    Mode: NULLABLE
# Column: updated_on                Type: TIMESTAMP  Mode: NULLABLE
# Column: latitude                  Type: FLOAT      Mode: NULLABLE
# Column: longitude                 Type: FLOAT      Mode: NULLABLE
# Column: location                  Type: STRING     Mode: NULLABLE

# %%
num_timestamp_fields = 2 # Put your answer here

# Check your answer
q_2.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_2.hint()
#q_2.solution()

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
# Query to select all the crimes (unique_key) and their "latitute" and "longitutude" for mapping
query = """
        SELECT 
            unique_key,
            latitude, 
            longitude
        FROM `bigquery-public-data.chicago_crime.crime`
        limit 100
        """

df = client.query(query).to_dataframe()

latitude = df['latitude']
longitude = df['longitude']
# Out:
# /usr/local/lib/python3.11/dist-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
fields_for_plotting = ['latitude', 'longitude'] # Put your answers here

# Check your answer
q_3.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
# q_3.hint()
# q_3.solution()

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %%
client.list_rows(table,max_results=5).to_dataframe()
# Out:
#    unique_key case_number                      date                 block  \
# 0    13790140    JJ199357 2025-03-23 04:00:00+00:00     0000X E WACKER DR
# 1     1663655     G445529 2001-07-28 22:10:00+00:00    001XX N CLINTON ST
# 2     1866824     G704843 2001-11-23 22:45:00+00:00  003XX S JEFFERSON ST
# 3     6355685    HP443356 2008-07-10 01:35:00+00:00      007XX W ADAMS ST
# 4     7472568    HS274608 2010-04-24 20:20:00+00:00      001XX S CANAL ST
#
#    iucr             primary_type     description location_description  arrest  \
# 0  0281  CRIMINAL SEXUAL ASSAULT  NON-AGGRAVATED        HOTEL / MOTEL   False
# 1  0281      CRIM SEXUAL ASSAULT  NON-AGGRAVATED               STREET   False
# 2  031A                  ROBBERY  ARMED: HANDGUN                ALLEY   False
# 3  031A                  ROBBERY  ARMED: HANDGUN             SIDEWALK   False
# 4  031A                  ROBBERY  ARMED: HANDGUN               STREET    True
#
#    domestic  ...  ward  community_area  fbi_code  x_coordinate y_coordinate  \
# 0     False  ...    42              32        02     1177009.0    1902589.0
# 1     False  ...  <NA>            <NA>        02     1172726.0    1901652.0
# 2     False  ...  <NA>            <NA>        03     1172343.0    1898647.0
# 3     False  ...     2              28        03     1171809.0    1899342.0
# 4     False  ...     2              28        03     1173161.0    1899677.0
#
#    year                updated_on   latitude  longitude  \
# 0  2025 2025-11-02 15:41:09+00:00  41.888046 -87.625414
# 1  2001 2015-08-17 15:03:40+00:00  41.885571 -87.641170
# 2  2001 2015-08-17 15:03:40+00:00  41.877333 -87.642665
# 3  2008 2018-02-28 15:56:25+00:00  41.879252 -87.644605
# 4  2010 2018-02-10 15:50:01+00:00  41.880141 -87.639631
#
#                         location
# 0  (41.888045958, -87.625413826)
# 1  (41.885570655, -87.641170046)
# 2  (41.877333207, -87.642665292)
# 3  (41.879252109, -87.644605498)
# 4  (41.880141491, -87.639631281)
#
# [5 rows x 22 columns]

# %% [markdown]
# # Keep going
#
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](https://www.kaggle.com/dansbecker/select-from-where).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-sql/discussion) to chat with other learners.*
